# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1   -0.150678
#    2    0.857930
#    3   -1.480412
# b  1    0.419739
#    2    0.283065
# c  3    0.050650
#    1   -0.054429
# d  2   -1.702209
#    3   -0.847543
# dtype: float64

# %%
data1 = data.unstack()
data1
# Out:
#           1         2         3
# a -0.150678  0.857930 -1.480412
# b  0.419739  0.283065       NaN
# c -0.054429       NaN  0.050650
# d       NaN -1.702209 -0.847543

# %%
data1.stack()
# Out:
# a  1   -0.150678
#    2    0.857930
#    3   -1.480412
# b  1    0.419739
#    2    0.283065
#    3         NaN
# c  1   -0.054429
#    2         NaN
#    3    0.050650
# d  1         NaN
#    2   -1.702209
#    3   -0.847543
# dtype: float64
