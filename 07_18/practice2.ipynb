# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1   -0.150678
#    2    0.857930
#    3   -1.480412
# b  1    0.419739
#    2    0.283065
# c  3    0.050650
#    1   -0.054429
# d  2   -1.702209
#    3   -0.847543
# dtype: float64

# %%
data1 = data.unstack()
data1
# Out:
#           1         2         3
# a -0.150678  0.857930 -1.480412
# b  0.419739  0.283065       NaN
# c -0.054429       NaN  0.050650
# d       NaN -1.702209 -0.847543

# %%
data1.stack()
# Out:
# a  1   -0.150678
#    2    0.857930
#    3   -1.480412
# b  1    0.419739
#    2    0.283065
#    3         NaN
# c  1   -0.054429
#    2         NaN
#    3    0.050650
# d  1         NaN
#    2   -1.702209
#    3   -0.847543
# dtype: float64

# %%
import numpy as np
import pandas as pd

frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                    index=[['a','a','b','b'],[1, 2, 1, 2]],
                    columns=[['台北','台北','台中'],['Green','Red','Green']])
frame.index.names = ['key1', 'key2']
frame.columns.names = ['縣市','顏色']
frame
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11

# %%
frame1 = frame.stack(['顏色','縣市'])
frame1
# Out:
# key1  key2  顏色     縣市
# a     1     Green  台北     0
#             Red    台北     1
#             Green  台中     2
#       2     Green  台北     3
#             Red    台北     4
#             Green  台中     5
# b     1     Green  台北     6
#             Red    台北     7
#             Green  台中     8
#       2     Green  台北     9
#             Red    台北    10
#             Green  台中    11
# dtype: int64

# %%
frame1.unstack('key1')
# Out:
# key1           a   b
# key2 顏色    縣市
# 1    Green 台中  2   8
#            台北  0   6
#      Red   台北  1   7
# 2    Green 台中  5  11
#            台北  3   9
#      Red   台北  4  10

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  1.680322  0.502917
# 1    a  two -0.921928  0.722615
# 2    b  one -1.033627  0.844423
# 3    b  two -0.194192 -1.425188
# 4    a  one -0.167569 -1.313352

# %%
df[['key1','data1','data2']].groupby('key1').sum()
# Out:
#          data1     data2
# key1
# a     0.590825 -0.087820
# b    -1.227819 -0.580765

# %%
df[['key1','data1','data2']].groupby('key1').mean()
# Out:
#          data1     data2
# key1
# a     0.196942 -0.029273
# b    -0.613909 -0.290383

# %%
df1 = df.groupby(['key1','key2']).sum()
df1.columns.name = "data"
df1
# Out:
# data          data1     data2
# key1 key2
# a    one   1.512753 -0.810436
#      two  -0.921928  0.722615
# b    one  -1.033627  0.844423
#      two  -0.194192 -1.425188

# %%
df1.stack().unstack(['key1','data'])
# Out:
# key1         a                   b
# data     data1     data2     data1     data2
# key2
# one   1.512753 -0.810436 -1.033627  0.844423
# two  -0.921928  0.722615 -0.194192 -1.425188
