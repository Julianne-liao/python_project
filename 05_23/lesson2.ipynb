# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i = 0
i += 1
i += 2
i += 3
i += 4

print(i)
# Out:
# 10

# %%
total = 0
for i in range(1,5):
    total += i

print(total)
# Out:
# 10

# %%
total = 0
for i in range(50,101):
    total += i

print(total)
# Out:
# 3825
