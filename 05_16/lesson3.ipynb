# %%
#學生總分300分
#有些學生可以加分5%

score=int(input("請輸入學生分數:"))
is_add=input("是否符合加分條件(y,n)")

if is_add=="y":
    socre=score*1.05
    score=round((score*1.05),0)
    
print ("總分數為：",score)
# Out:
# 總分數為： 250
