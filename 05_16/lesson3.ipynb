# %%
#學生總分300分
#有些學生可以加分5%
while True:
    try:
        score=int(input("請輸入學生分數(最高300分):"))
        break
    except ValueError:
        print("輸入錯誤，請輸入整數!")
        
is_add=input("是否符合加分條件?(y,n)")

if is_add == "y":
    socre=score*1.05
    score=round((score*1.05),0)

if score > 300:
    score = 300
    
print ("總分數為：",score)
# Out:
# 總分數為： 200.0
